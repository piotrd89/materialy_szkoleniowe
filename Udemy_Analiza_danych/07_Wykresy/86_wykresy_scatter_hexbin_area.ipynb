# %% [markdown]
# # Wstęp

# %%
import pandas as pd
import numpy as np
import matplotlib as np
# %matplotlib inline

# %%
autos = pd.read_csv('http://piotrdomagala.pl/data/autos.csv', encoding='latin-1')

# %%
autos.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dateCrawled</th>
#       <th>name</th>
#       <th>seller</th>
#       <th>offerType</th>
#       <th>price</th>
#       <th>abtest</th>
#       <th>vehicleType</th>
#       <th>yearOfRegistration</th>
#       <th>gearbox</th>
#       <th>powerPS</th>
#       <th>model</th>
#       <th>kilometer</th>
#       <th>monthOfRegistration</th>
#       <th>fuelType</th>
#       <th>brand</th>
#       <th>notRepairedDamage</th>
#       <th>dateCreated</th>
#       <th>nrOfPictures</th>
#       <th>postalCode</th>
#       <th>lastSeen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2016-03-24 11:52:17</td>
#       <td>Golf_3_1.6</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>480</td>
#       <td>test</td>
#       <td>NaN</td>
#       <td>1993</td>
#       <td>manuell</td>
#       <td>0</td>
#       <td>golf</td>
#       <td>150000</td>
#       <td>0</td>
#       <td>benzin</td>
#       <td>volkswagen</td>
#       <td>NaN</td>
#       <td>2016-03-24 00:00:00</td>
#       <td>0</td>
#       <td>70435</td>
#       <td>2016-04-07 03:16:57</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2016-03-24 10:58:45</td>
#       <td>A5_Sportback_2.7_Tdi</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>18300</td>
#       <td>test</td>
#       <td>coupe</td>
#       <td>2011</td>
#       <td>manuell</td>
#       <td>190</td>
#       <td>NaN</td>
#       <td>125000</td>
#       <td>5</td>
#       <td>diesel</td>
#       <td>audi</td>
#       <td>ja</td>
#       <td>2016-03-24 00:00:00</td>
#       <td>0</td>
#       <td>66954</td>
#       <td>2016-04-07 01:46:50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2016-03-14 12:52:21</td>
#       <td>Jeep_Grand_Cherokee_"Overland"</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>9800</td>
#       <td>test</td>
#       <td>suv</td>
#       <td>2004</td>
#       <td>automatik</td>
#       <td>163</td>
#       <td>grand</td>
#       <td>125000</td>
#       <td>8</td>
#       <td>diesel</td>
#       <td>jeep</td>
#       <td>NaN</td>
#       <td>2016-03-14 00:00:00</td>
#       <td>0</td>
#       <td>90480</td>
#       <td>2016-04-05 12:47:46</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2016-03-17 16:54:04</td>
#       <td>GOLF_4_1_4__3TÜRER</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>1500</td>
#       <td>test</td>
#       <td>kleinwagen</td>
#       <td>2001</td>
#       <td>manuell</td>
#       <td>75</td>
#       <td>golf</td>
#       <td>150000</td>
#       <td>6</td>
#       <td>benzin</td>
#       <td>volkswagen</td>
#       <td>nein</td>
#       <td>2016-03-17 00:00:00</td>
#       <td>0</td>
#       <td>91074</td>
#       <td>2016-03-17 17:40:17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2016-03-31 17:25:20</td>
#       <td>Skoda_Fabia_1.4_TDI_PD_Classic</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>3600</td>
#       <td>test</td>
#       <td>kleinwagen</td>
#       <td>2008</td>
#       <td>manuell</td>
#       <td>69</td>
#       <td>fabia</td>
#       <td>90000</td>
#       <td>7</td>
#       <td>diesel</td>
#       <td>skoda</td>
#       <td>nein</td>
#       <td>2016-03-31 00:00:00</td>
#       <td>0</td>
#       <td>60437</td>
#       <td>2016-04-06 10:17:21</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import re
regex = re.compile('.toyota.*corolla.*',re.IGNORECASE)
filter1 = autos['name'].apply(lambda x: bool(regex.search(x)))
filter2 = autos['price'] < 12000
filter3 = autos['yearOfRegistration'] >= 1990
tc = autos[filter1 & filter2 & filter3]

# %%
import re
regex = re.compile('.Audi.*a4.*',re.IGNORECASE)
filter1 = autos['name'].apply(lambda x: bool(regex.search(x)))
filter2 = autos['price'] < 12000
filter3 = autos['yearOfRegistration'] >= 1990
audi = autos[filter1 & filter2 & filter3]

# %%
tc.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dateCrawled</th>
#       <th>name</th>
#       <th>seller</th>
#       <th>offerType</th>
#       <th>price</th>
#       <th>abtest</th>
#       <th>vehicleType</th>
#       <th>yearOfRegistration</th>
#       <th>gearbox</th>
#       <th>powerPS</th>
#       <th>model</th>
#       <th>kilometer</th>
#       <th>monthOfRegistration</th>
#       <th>fuelType</th>
#       <th>brand</th>
#       <th>notRepairedDamage</th>
#       <th>dateCreated</th>
#       <th>nrOfPictures</th>
#       <th>postalCode</th>
#       <th>lastSeen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19202</th>
#       <td>2016-03-13 06:36:16</td>
#       <td>Moin_Guten_Tag_Suche_Toyota_Auto_wie_zB._Picni...</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>0</td>
#       <td>test</td>
#       <td>NaN</td>
#       <td>1990</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>150000</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>sonstige_autos</td>
#       <td>NaN</td>
#       <td>2016-03-13 00:00:00</td>
#       <td>0</td>
#       <td>27777</td>
#       <td>2016-03-13 07:52:30</td>
#     </tr>
#     <tr>
#       <th>31795</th>
#       <td>2016-03-17 01:37:02</td>
#       <td>??Moin_Suche_Dringend_Toyota_Auto_wie_zB._Picn...</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>0</td>
#       <td>test</td>
#       <td>NaN</td>
#       <td>1990</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>150000</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>toyota</td>
#       <td>NaN</td>
#       <td>2016-03-17 00:00:00</td>
#       <td>0</td>
#       <td>27777</td>
#       <td>2016-03-17 06:00:25</td>
#     </tr>
#     <tr>
#       <th>36846</th>
#       <td>2016-03-14 13:43:41</td>
#       <td>zuverlaessiger__top_gepflegter_Toyota_Corolla.</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>3700</td>
#       <td>test</td>
#       <td>limousine</td>
#       <td>2003</td>
#       <td>manuell</td>
#       <td>97</td>
#       <td>corolla</td>
#       <td>125000</td>
#       <td>6</td>
#       <td>benzin</td>
#       <td>toyota</td>
#       <td>NaN</td>
#       <td>2016-03-14 00:00:00</td>
#       <td>0</td>
#       <td>48455</td>
#       <td>2016-03-29 07:17:29</td>
#     </tr>
#     <tr>
#       <th>57177</th>
#       <td>2016-03-14 14:53:46</td>
#       <td>Zuverlaessiger_Toyota_Corolla</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>850</td>
#       <td>control</td>
#       <td>limousine</td>
#       <td>1998</td>
#       <td>manuell</td>
#       <td>86</td>
#       <td>corolla</td>
#       <td>150000</td>
#       <td>5</td>
#       <td>benzin</td>
#       <td>toyota</td>
#       <td>nein</td>
#       <td>2016-03-14 00:00:00</td>
#       <td>0</td>
#       <td>56584</td>
#       <td>2016-03-23 19:45:46</td>
#     </tr>
#     <tr>
#       <th>83436</th>
#       <td>2016-03-17 09:55:10</td>
#       <td>Ich_biete_einen_Toyota_Corolla_zum_Kauf_an.</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>2900</td>
#       <td>test</td>
#       <td>kombi</td>
#       <td>2000</td>
#       <td>automatik</td>
#       <td>79</td>
#       <td>corolla</td>
#       <td>150000</td>
#       <td>11</td>
#       <td>benzin</td>
#       <td>toyota</td>
#       <td>nein</td>
#       <td>2016-03-17 00:00:00</td>
#       <td>0</td>
#       <td>42799</td>
#       <td>2016-04-06 19:15:51</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
audi.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dateCrawled</th>
#       <th>name</th>
#       <th>seller</th>
#       <th>offerType</th>
#       <th>price</th>
#       <th>abtest</th>
#       <th>vehicleType</th>
#       <th>yearOfRegistration</th>
#       <th>gearbox</th>
#       <th>powerPS</th>
#       <th>model</th>
#       <th>kilometer</th>
#       <th>monthOfRegistration</th>
#       <th>fuelType</th>
#       <th>brand</th>
#       <th>notRepairedDamage</th>
#       <th>dateCreated</th>
#       <th>nrOfPictures</th>
#       <th>postalCode</th>
#       <th>lastSeen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1257</th>
#       <td>2016-03-22 00:38:14</td>
#       <td>+++Audi_A4_1.8_TFSI_Ambition+++</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>10900</td>
#       <td>control</td>
#       <td>limousine</td>
#       <td>2008</td>
#       <td>manuell</td>
#       <td>160</td>
#       <td>a4</td>
#       <td>100000</td>
#       <td>5</td>
#       <td>benzin</td>
#       <td>audi</td>
#       <td>nein</td>
#       <td>2016-03-21 00:00:00</td>
#       <td>0</td>
#       <td>33129</td>
#       <td>2016-03-22 06:47:45</td>
#     </tr>
#     <tr>
#       <th>1707</th>
#       <td>2016-03-15 20:43:10</td>
#       <td>Audi_Audi_A4_1.8_Sonder_Ausstatung__Tuev___Tun...</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>1500</td>
#       <td>test</td>
#       <td>limousine</td>
#       <td>1996</td>
#       <td>manuell</td>
#       <td>182</td>
#       <td>a4</td>
#       <td>150000</td>
#       <td>12</td>
#       <td>benzin</td>
#       <td>audi</td>
#       <td>nein</td>
#       <td>2016-03-15 00:00:00</td>
#       <td>0</td>
#       <td>59929</td>
#       <td>2016-04-01 05:16:51</td>
#     </tr>
#     <tr>
#       <th>1988</th>
#       <td>2016-04-02 13:57:41</td>
#       <td>Audi_Audi_A4_1.6_Limousine</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>3300</td>
#       <td>test</td>
#       <td>limousine</td>
#       <td>1996</td>
#       <td>manuell</td>
#       <td>101</td>
#       <td>a4</td>
#       <td>80000</td>
#       <td>3</td>
#       <td>benzin</td>
#       <td>audi</td>
#       <td>nein</td>
#       <td>2016-04-02 00:00:00</td>
#       <td>0</td>
#       <td>85114</td>
#       <td>2016-04-06 12:16:42</td>
#     </tr>
#     <tr>
#       <th>4425</th>
#       <td>2016-04-01 15:54:34</td>
#       <td>Tausche/_verkaufe_Audi_A4!_Lesen_lohnt_sich!</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>0</td>
#       <td>test</td>
#       <td>limousine</td>
#       <td>1995</td>
#       <td>automatik</td>
#       <td>125</td>
#       <td>a4</td>
#       <td>150000</td>
#       <td>0</td>
#       <td>benzin</td>
#       <td>audi</td>
#       <td>NaN</td>
#       <td>2016-04-01 00:00:00</td>
#       <td>0</td>
#       <td>63683</td>
#       <td>2016-04-07 13:50:21</td>
#     </tr>
#     <tr>
#       <th>5049</th>
#       <td>2016-04-03 21:40:37</td>
#       <td>auto_Audi_A4</td>
#       <td>privat</td>
#       <td>Angebot</td>
#       <td>250</td>
#       <td>test</td>
#       <td>NaN</td>
#       <td>2017</td>
#       <td>manuell</td>
#       <td>101</td>
#       <td>a4</td>
#       <td>20000</td>
#       <td>0</td>
#       <td>benzin</td>
#       <td>audi</td>
#       <td>nein</td>
#       <td>2016-04-03 00:00:00</td>
#       <td>0</td>
#       <td>38723</td>
#       <td>2016-04-05 22:18:33</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
tc.plot(kind='scatter', x='yearOfRegistration', y='price')
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
ax = audi.plot.scatter(x='yearOfRegistration', y='price', color = 'Blue', label='Audi')
tc.plot.scatter(x='yearOfRegistration', y='price', color='Green', label='Toyota', ax=ax)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
tc.plot.hexbin(x='yearOfRegistration', y='price', gridsize=10, title='Toyota')
audi.plot.hexbin(x='yearOfRegistration', y='price', gridsize=10, title='Audi')
# Out:
# <Axes: title={'center': 'Audi'}, xlabel='yearOfRegistration', ylabel='price'>

# %%
tc_counts = tc['yearOfRegistration'].value_counts().sort_index()

# %%
tc_counts.head()
# Out:
# <pre>1990    3
# 1996    2
# 1997    2
# 1998    2
# 2000    1
# Name: yearOfRegistration, dtype: int64</pre>

# %%
audi_counts = audi['yearOfRegistration'].value_counts().sort_index()

# %%
audi_counts.head()
# Out:
# <pre>1994     3
# 1995    50
# 1996    39
# 1997    53
# 1998    24
# Name: yearOfRegistration, dtype: int64</pre>

# %%
car_counts = pd.DataFrame(index= tc_counts.index.append(audi_counts.index).unique())

# %%
car_counts['Toyota'] = tc_counts

# %%
car_counts['Audi'] = audi_counts

# %%
car_counts.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Toyota</th>
#       <th>Audi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1990</th>
#       <td>3.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1996</th>
#       <td>2.0</td>
#       <td>39.0</td>
#     </tr>
#     <tr>
#       <th>1997</th>
#       <td>2.0</td>
#       <td>53.0</td>
#     </tr>
#     <tr>
#       <th>1998</th>
#       <td>2.0</td>
#       <td>24.0</td>
#     </tr>
#     <tr>
#       <th>2000</th>
#       <td>1.0</td>
#       <td>32.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
car_counts.fillna(0,inplace=True)

# %%
car_counts.sort_index(inplace=True)

# %%
car_counts.plot()
# Out:
# <Axes: >

# %%
car_counts.plot(kind='area')
# Out:
# <Axes: >

# %% [markdown]
# # Zadanie

# %%
def convert_to_seconds(x):
    try:
        return pd.Timedelta(x).total_seconds()
    except:
        return None

marathon['TimeSeconds'] = marathon['40K'].apply(convert_to_seconds)
marathon.dropna(subset=['TimeSeconds'], inplace=True)
marathon.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>M/F</th>
#       <th>Country</th>
#       <th>40K</th>
#       <th>TimeSeconds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24</td>
#       <td>M</td>
#       <td>KEN</td>
#       <td>2:02:53</td>
#       <td>7373.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>30</td>
#       <td>M</td>
#       <td>USA</td>
#       <td>2:03:14</td>
#       <td>7394.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25</td>
#       <td>M</td>
#       <td>JPN</td>
#       <td>2:03:38</td>
#       <td>7418.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>32</td>
#       <td>M</td>
#       <td>USA</td>
#       <td>2:04:35</td>
#       <td>7475.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>31</td>
#       <td>M</td>
#       <td>KEN</td>
#       <td>2:05:00</td>
#       <td>7500.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
marathon.plot(kind='scatter', x='Age', y='TimeSeconds')
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
marathon_m  = marathon[marathon['M/F']=='M']
marathon_f  = marathon[marathon['M/F']=='F']

# %%
ax = marathon_m.plot.scatter(x='Age', y='TimeSeconds', label='M' )
marathon_f.plot.scatter(x='Age', y='TimeSeconds', color='LightBlue', ax=ax)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
marathon_m.plot.hexbin(x='Age', y='TimeSeconds', gridsize=30)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
marathon_f.plot.hexbin(x='Age', y='TimeSeconds', gridsize=30)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>
