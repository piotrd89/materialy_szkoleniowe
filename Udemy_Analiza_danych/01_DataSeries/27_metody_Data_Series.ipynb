# %%
# --------------------Wstęp -----------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
monoliticList = (1,2,4,67,99)
monotonicSeries = pd.Series(monoliticList)
monotonicSeries
# Out:
# <pre>0     1
# 1     2
# 2     4
# 3    67
# 4    99
# dtype: int64</pre>

# %%
monotonicSeries.sum()
# Out:
# 173

# %%
monotonicSeries.min()
# Out:
# 1

# %%
monotonicSeries.mean()
# Out:
# 34.6

# %%
monotonicSeries.count()
# Out:
# 5

# %%
monotonicSeries.size
# Out:
# 5

# %%
monotonicSeries.product()
# Out:
# 53064

# %%
monotonicSeries.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
monotonicSeries.keys()
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
monotonicSeries.values
# Out:
# <pre>array([ 1,  2,  4, 67, 99])</pre>

# %%
monotonicSeries.to_list()
# Out:
# [1, 2, 4, 67, 99]

# %%
monotonicSeries.add(10)
# Out:
# <pre>0     11
# 1     12
# 2     14
# 3     77
# 4    109
# dtype: int64</pre>

# %%
monotonicSeries
# Out:
# <pre>0     1
# 1     2
# 2     4
# 3    67
# 4    99
# dtype: int64</pre>

# %%
newSeries = monotonicSeries.add(10)
newSeries
# Out:
# <pre>0     11
# 1     12
# 2     14
# 3     77
# 4    109
# dtype: int64</pre>

# %%
currencies = ['USD','EUR','PLN','EUR','EUR']
countries = ['USA','Spain','Poland','Portugal','Italy']

# %%
curSer = pd.Series(data=countries,index=currencies)
curSer
# Out:
# <pre>USD         USA
# EUR       Spain
# PLN      Poland
# EUR    Portugal
# EUR       Italy
# dtype: object</pre>

# %%
dictCountry = {"USD":"USA", "USD":"USA"}
dictCountry
# Out:
# {'USD': 'USA'}

# %%
dictCountry = {"USD":"USA", "USD":"Ecuador"}
dictCountry
# Out:
# {'USD': 'Ecuador'}

# %%
# -------------------------- ZADANIE -----------------------------
cities = ["Szanghaj","Pekin", "Stambuł"]
population = [24183300, 20794100, 15030000]

citipop = pd.Series(index=cities,data=population)
citipop

citipop.sum()
# Out:
# 60007400

# %%
citipop.mean()
# Out:
# 20002466.666666668

# %%
citipop.index
# Out:
# Index(['Szanghaj', 'Pekin', 'Stambuł'], dtype='object')

# %%
citipop.keys()
# Out:
# Index(['Szanghaj', 'Pekin', 'Stambuł'], dtype='object')

# %%
citipop.values
# Out:
# <pre>array([24183300, 20794100, 15030000])</pre>
