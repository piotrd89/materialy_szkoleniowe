# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
pok = pd.read_csv("../workspace_files/pokemon.csv", usecols=["Name"]).squeeze()
pok
# Out:
# <pre>0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object</pre>

# %%
type(pok)
# Out:
# pandas.core.series.Series

# %%
len(pok)
# Out:
# 800

# %%
sorted(pok.head(5))
# Out:
# ['Bulbasaur', 'Charmander', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur']

# %%
type(sorted(pok.head(5)))
# Out:
# list

# %%
list(pok.head(5))
# Out:
# ['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur', 'Charmander']

# %%
type(list(pok.head(5)))
# Out:
# list

# %%
dict(pok.head())
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'VenusaurMega Venusaur',
#  4: 'Charmander'}

# %%
type(dict(pok.head()))
# Out:
# dict

# %%
min(pok)
# Out:
# 'Abomasnow'

# %%
max(pok)
# Out:
# 'Zygarde50% Forme'

# %%
pok.name
# Out:
# 'Name'

# %%
pok.name = "Imię pokemona"
pok.name
# Out:
# 'Imię pokemona'

# %%
# ---------------------------- ZADANIE -------------------------------

from zipfile import ZipFile
from io import BytesIO
import urllib.request as urllib2

r = urllib2.urlopen("https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2018.zip").read()
file = ZipFile(BytesIO(r))

survey_csv = file.open("survey_results_public.csv")
salary = pd.read_csv(survey_csv, usecols=["Salary"]).dropna().squeeze()
salary.head(5)
# Out:
# <ipython-input-27-558716faaa88>:11: DtypeWarning: Columns (52) have mixed types. Specify dtype option on import or set low_memory=False.
#   salary = pd.read_csv(survey_csv, usecols=["Salary"]).dropna().squeeze()
# <pre>1     51000
# 4    260000
# 5     30000
# 6    120000
# 8    250000
# Name: Salary, dtype: object</pre>

# %%
len(salary)
# Out:
# 50578

# %%
min(salary)
# Out:
# '.0'

# %%
max(salary.head())
# Out:
# '51000'

# %%
list(salary.head(5))
# Out:
# ['51000', '260000', '30000', '120000', '250000']

# %%
dict(salary.head())
# Out:
# {1: '51000', 4: '260000', 5: '30000', 6: '120000', 8: '250000'}

# %%
listSalarySorted = sorted(salary, reverse=True)
listSalarySorted[:5]
# Out:
# ['999999999999999999999999999999',
#  '99999999999999999',
#  '99999999',
#  '99999',
#  '99999']

# %%
salary.name = "Pensja osoby"
salary.head()
# Out:
# <pre>1     51000
# 4    260000
# 5     30000
# 6    120000
# 8    250000
# Name: Pensja osoby, dtype: object</pre>
