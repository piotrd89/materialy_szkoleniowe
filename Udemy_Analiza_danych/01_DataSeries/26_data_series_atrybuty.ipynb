# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
cities = ['Londyn', 'Warszawa', 'Berlin', 'Paryż']
citiesSeries = pd.Series(cities)

# %%
citiesSeries
citiesSeries.size # ilość wartości w obiekcie Series
# Out:
# 4

# %%
citiesSeries.nbytes # rozmiar obiektu w pamięci [bajty]
# Out:
# 32

# %%
citiesSeries.is_unique # czy wartości są unikalne
# Out:
# True

# %%
citiesSeries.is_monotonic_increasing
# Out:
# False

# %%
citiesSeries.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
citiesSeries.values
# Out:
# <pre>array(['Londyn', 'Warszawa', 'Berlin', 'Paryż'], dtype=object)</pre>

# %%
citiesSeries.dtype
# Out:
# dtype('O')

# %%
citiesSeries.shape
# Out:
# (4,)

# %%
citiesSeries.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1)]

# %%
monotonicList = [1,2,4,67,99]
monotonicSeries = pd.Series(monotonicList)
monotonicSeries
# Out:
# <pre>0     1
# 1     2
# 2     4
# 3    67
# 4    99
# dtype: int64</pre>

# %%
monotonicSeries.is_monotonic_decreasing
monotonicSeries.is_monotonic_increasing
# Out:
# True

# %%
stringList=['Cola', 'Redbull', 'Sprite']
stringSeries = pd.Series(stringList)
