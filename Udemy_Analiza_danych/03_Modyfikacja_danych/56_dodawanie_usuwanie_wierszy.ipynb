# %% [markdown]
# # Wstęp

# %%
import pandas as pd
import numpy as np

# %%
frame = pd.read_csv('http://piotrdomagala.pl/data/sleep_time.csv', 
                    index_col='ID')
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#       <th>sleep_rem</th>
#       <th>sleep_cycle</th>
#       <th>awake</th>
#       <th>brainwt</th>
#       <th>bodywt</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Cheetah</td>
# ...

# %%
del frame['bodywt']
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#       <th>sleep_rem</th>
#       <th>sleep_cycle</th>
#       <th>awake</th>
#       <th>brainwt</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Cheetah</td>
#       <td>Acinonyx</td>
#       <td>carni</td>
# ...

# %%
frame.drop(axis=1, columns=['awake', 'brainwt'], inplace=True)

# %%
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#       <th>sleep_rem</th>
#       <th>sleep_cycle</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Cheetah</td>
#       <td>Acinonyx</td>
#       <td>carni</td>
#       <td>Carnivora</td>
#       <td>lc</td>
#       <td>12.1</td>
#       <td>NaN</td>
# ...

# %%
frame.drop(axis='columns', columns=['sleep_cycle'], inplace=True)
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#       <th>sleep_rem</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Cheetah</td>
#       <td>Acinonyx</td>
#       <td>carni</td>
#       <td>Carnivora</td>
#       <td>lc</td>
#       <td>12.1</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
frame.drop(columns='sleep_rem', inplace=True)

# %%
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Cheetah</td>
#       <td>Acinonyx</td>
#       <td>carni</td>
#       <td>Carnivora</td>
#       <td>lc</td>
#       <td>12.1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Owl monkey</td>
#       <td>Aotus</td>
#       <td>omni</td>
# ...

# %%
frame.drop(axis=0, labels=[1,2], inplace=True)
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Mountain beaver</td>
#       <td>Aplodontia</td>
#       <td>herbi</td>
#       <td>Rodentia</td>
#       <td>nt</td>
#       <td>14.4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Greater short-tailed shrew</td>
#       <td>Blarina</td>
# ...

# %%
frame.drop(axis='rows', labels=3, inplace=True)
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>Greater short-tailed shrew</td>
#       <td>Blarina</td>
#       <td>omni</td>
#       <td>Soricomorpha</td>
#       <td>lc</td>
#       <td>14.9</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Cow</td>
#       <td>Bos</td>
# ...

# %%
frame.drop(labels=4, inplace=True)
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>Cow</td>
#       <td>Bos</td>
#       <td>herbi</td>
#       <td>Artiodactyla</td>
#       <td>domesticated</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Three-toed sloth</td>
#       <td>Bradypus</td>
# ...

# %%
frame.drop(5, inplace=True) # argument labels/wiersze jest domyślnie ustawiony jako pierwszy stąd nie trzeba o nim pisać
frame.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>Three-toed sloth</td>
#       <td>Bradypus</td>
#       <td>herbi</td>
#       <td>Pilosa</td>
#       <td>NaN</td>
#       <td>14.4</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Northern fur seal</td>
#       <td>Callorhinus</td>
# ...

# %%
dict = {'name':'Panda4', 'genus':np.NaN, 'vore':np.NaN, 'order':np.NaN, 'conservation':np.NaN, 'sleep_total':10}

# %%
frame.append(dict,ignore_index=True)
# Out:
# <ipython-input-18-87c84804e10e>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   frame.append(dict,ignore_index=True)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Three-toed sloth</td>
#       <td>Bradypus</td>
#       <td>herbi</td>
#       <td>Pilosa</td>
#       <td>NaN</td>
#       <td>14.4</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
subset = frame[0:5]
frame.append(subset)
# Out:
# <ipython-input-19-5294c2e39481>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   frame.append(subset)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>genus</th>
#       <th>vore</th>
#       <th>order</th>
#       <th>conservation</th>
#       <th>sleep_total</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>Three-toed sloth</td>
#       <td>Bradypus</td>
# ...

# %% [markdown]
# # Zadanie

# %%
professions = pd.read_csv('http://piotrdomagala.pl/data/Prestige.csv')
professions.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>education</th>
#       <th>income</th>
#       <th>women</th>
#       <th>prestige</th>
#       <th>census</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gov.administrators</td>
#       <td>13.11</td>
#       <td>12351</td>
#       <td>11.16</td>
#       <td>68.8</td>
#       <td>1113</td>
#       <td>prof</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>general.managers</td>
#       <td>12.26</td>
#       <td>25879</td>
#       <td>4.02</td>
#       <td>69.1</td>
#       <td>1130</td>
#       <td>prof</td>
#     </tr>
# ...

# %%
dict = {'name':' data scientist', 'education':np.NaN, 'income':np.NaN, 'women':np.NaN,
        'prestige':np.NaN, 'census':np.NaN, 'type':np.NaN}

# %%
professions.append(dict, ignore_index=True)
# Out:
# <ipython-input-23-a1477e66904e>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   professions.append(dict, ignore_index=True)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>education</th>
#       <th>income</th>
#       <th>women</th>
#       <th>prestige</th>
#       <th>census</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gov.administrators</td>
#       <td>13.11</td>
#       <td>12351.0</td>
#       <td>11.16</td>
#       <td>68.8</td>
#       <td>1113.0</td>
#       <td>prof</td>
# ...

# %%
taxi = professions[professions["name"]=='taxi.drivers']
taxi
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>education</th>
#       <th>income</th>
#       <th>women</th>
#       <th>prestige</th>
#       <th>census</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>98</th>
#       <td>taxi.drivers</td>
#       <td>7.93</td>
#       <td>4224</td>
#       <td>3.59</td>
#       <td>25.1</td>
#       <td>9173</td>
#       <td>bc</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
professions.drop(98, inplace=True)
professions.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>education</th>
#       <th>income</th>
#       <th>women</th>
#       <th>prestige</th>
#       <th>census</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>96</th>
#       <td>train.engineers</td>
#       <td>8.49</td>
#       <td>8845</td>
#       <td>0.00</td>
#       <td>48.9</td>
#       <td>9131</td>
#       <td>bc</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>bus.drivers</td>
#       <td>7.58</td>
#       <td>5562</td>
#       <td>9.47</td>
#       <td>35.9</td>
#       <td>9171</td>
#       <td>bc</td>
#     </tr>
#     <tr>
# ...

# %%
professions = professions.append(taxi)
professions.tail()
# Out:
# <ipython-input-28-0dec8069b193>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   professions = professions.append(taxi)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>education</th>
#       <th>income</th>
#       <th>women</th>
#       <th>prestige</th>
#       <th>census</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>97</th>
#       <td>bus.drivers</td>
#       <td>7.58</td>
#       <td>5562</td>
#       <td>9.47</td>
#       <td>35.9</td>
#       <td>9171</td>
#       <td>bc</td>
#     </tr>
#     <tr>
# ...

# %%
del professions ["census"]
professions.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>education</th>
#       <th>income</th>
#       <th>women</th>
#       <th>prestige</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>97</th>
#       <td>bus.drivers</td>
#       <td>7.58</td>
#       <td>5562</td>
#       <td>9.47</td>
#       <td>35.9</td>
#       <td>bc</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>longshoremen</td>
#       <td>8.37</td>
#       <td>4753</td>
#       <td>0.00</td>
#       <td>26.1</td>
#       <td>bc</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>typesetters</td>
#       <td>10.00</td>
# ...

# %%
professions.drop(columns='type', inplace=True)
professions.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>education</th>
#       <th>income</th>
#       <th>women</th>
#       <th>prestige</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>97</th>
#       <td>bus.drivers</td>
#       <td>7.58</td>
#       <td>5562</td>
#       <td>9.47</td>
#       <td>35.9</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>longshoremen</td>
#       <td>8.37</td>
#       <td>4753</td>
#       <td>0.00</td>
#       <td>26.1</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>typesetters</td>
#       <td>10.00</td>
#       <td>6462</td>
#       <td>13.58</td>
#       <td>42.2</td>
# ...
